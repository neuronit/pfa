# %% [markdown]
# ## Feuille 1 BackEnd
# -----------------------------------
# Dans ce fichier se trouvera les premières implémentations du projet ainsi que les tests de l'equipe pour s'approprier IPython Notebook.

# %% [markdown]
# #### Raccourcis utiles
# Shit+Entrée : Execute le bloc dans lequel vous êtes.
#
# Ctrl+Entrée : Execute le bloc sur place et ne crée pas de bloc supplémentaire en dessous.
#
# Ctrl+m m : Permet de transformer une cellule Python en une cellule Markdown.
#
# Ctrl+m y : Transforme votre bloc en bloc Python utile quand il est de base en Markdown
#
# Ctrl+m a : Crée un bloc au dessus du bloc dans le bloc dans lequel vous êtes (above)
#
# Ctrl+m b: Crée un bloc en dessous du bloc dans le bloc dans lequel vous êtes (below).
#
# Ctrl+s: Le classique enregistre.
#
# Ctrl+m x/c/v/d : Coupe/Copie/Colle/Supprime le bloc/la cellule.
#
#
# #### Un peu moins utile
#
# Ctrl+m - : Découpe la cellule en deux
#
# ##### Pour les autres commandes, comme arréter le processus, vous trouverez tout dans Cell.
# ---------------------------

# %%
action = -1
reward = -action
print reward

print abs(-3)
# Out:
# 1
# 3

# %%
import numpy as np


from neuralNetworkMaster import *
SEN = MLP(4,3,4)
samples = np.zeros([6, 4])
SEN.reset()
samples[0] = (0,0,0,0)
samples[1] = (1,1,1,1)
samples[2] = (0,1,0,1)
samples[3] = (1,1,0,0)
samples[4] = (1,0,1,1)
samples[5] = (0.5,0,0.5,0.3)
Encode(SEN,samples)
# Out:
# Starting learning ...
# Learning complete
# sample number     : 0
# input             : [ 0.  0.  0.  0.]
# calculated output : [-0.02896515 -0.0229153  -0.0356409  -0.04755669]
#
# sample number     : 1
# input             : [ 1.  1.  1.  1.]
# calculated output : [ 0.98215676  0.95800004  0.95530385  0.98477648]
#
# sample number     : 2
# input             : [ 0.  1.  0.  1.]
# calculated output : [-0.01827085  0.99933022 -0.00600209  0.97532821]
#
# sample number     : 3
# input             : [ 1.  1.  0.  0.]
# calculated output : [ 0.95679748  0.967827   -0.06750155 -0.0725285 ]
#
# sample number     : 4
# input             : [ 1.  0.  1.  1.]
# calculated output : [ 0.98031763 -0.04583333  0.98195467  0.96774951]

# %%
from pfa.gym import test
# Out:
# [2017-01-04 14:46:47,946] Making new env: CartPole-v0
# Mon action : droite
# somme precedente : 0.0456764975388 somme actuelle  0.0925338146864
# coef x 0.00376856979719 coef t 0.0887652448892
# Mon action : droite
# somme precedente : 0.0925338146864 somme actuelle  0.126745706053
# coef x 0.00242410915132 coef t 0.124321596901
# Mon action : droite
# somme precedente : 0.126745706053 somme actuelle  0.194211802357
# coef x 0.000222612213453 coef t 0.193989190143
# Mon action :
#  droite
# somme precedente : 0.194211802357 somme actuelle  0.302158932979
# coef x 0.00417212253721 coef t 0.297986810442
# Mon action : droite
# somme precedente : 0.302158932979 somme actuelle  0.446162918269
# coef x 0.00942538859586 coef t 0.436737529673
# Mon action : droite
# somme precedente : 0.446162918269 somme actuelle  0.626842387741
# coef x 0.015983675963 coef t 0.610858711778
# Mon action : droite
# somme precedente : 0.626842387741 somme actuelle  0.844995451167
# ...

# %%
int(3.5)
# Out:
# 3
